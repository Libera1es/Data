# %%
from selenium import webdriver
from selenium.webdriver.common.by import By  # webページの要素の選択
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options  # chromeを動かす際にオプションをせってい

chrome_driver_path = "D:\FreeSoft\chromedriver-win64\chromedriver-win64\chromedriver.exe"
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)

url = "https://qiita.com/"  # QiitaのURL
driver.get(url)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\F'
# <>:6: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\Tsunc\AppData\Local\Temp\ipykernel_17740\1020974330.py:6: SyntaxWarning: invalid escape sequence '\F'
#   chrome_driver_path = "D:\FreeSoft\chromedriver-win64\chromedriver-win64\chromedriver.exe"

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By  # webページの要素の選択
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options  # chromeを動かす際にオプションをせってい

chrome_driver_path = r"D:\FreeSoft\chromedriver-win64\chromedriver-win64\chromedriver.exe"
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)

url = "https://carview.yahoo.co.jp/ncar/catalog/toyota/landcruiser_300/FMC001-MC002/grade/"  # QiitaのURL
driver.get(url)  # driverでURLのページを開きます

# それぞれの記事は、class="style-l2axsx"であり、
# 記事のリンクは、記事内で探すaタグの一番最初のもの.hrefで、
# 記事タイトルは、記事内で探すh2タグの.innerTextで取得できます

# 記事のタイトルを入れる配列
titles = []

# 記事のurlを入れる配列
urls = []

# ここから、driverで要素を見つけていきます
# driverで要素を見つけるには、[ driver.find_element ] もしくは、[ find_elements ] を用います
# 前者は単一の要素もしくは初めに見つけた要素のみ、後者は複数の要素を見つけます

# まず、表示されている記事全部を取得します
# クラスでの要素の参照は、driver.find_elements(By.CLASS_NAME, クラス名)　とします
articles = driver.find_elements(By.CSS_SELECTOR, "span.inline-txt")
#articles = driver.find_elements(By.CLASS_NAME, "inline-txt")

# それでは、articlesの全ての記事のタイトルとURLを配列に納めていきます
for article in articles:
    # 要素をタグ名（a, h1, bodyなど）で取得する場合は、
    # driver.find_elements(By.TAG_NAME, タグ名)　とします
    # driver の部分は、その要素が入っている要素でも可能です

    # タイトルはinnerTextなので、[ .text ] で取得します
    #title = article.find_element(By.XPATH, "h2").text
    title = article.text
    # titles、urlsのそれぞれの配列に、取得したtitle、urlを入れます
    titles.append(title)

# 最後に、記事のタイトルとその記事のURLを出力します
for i in range(len(titles)):
    print(titles[i])
driver.quit()
# Out:
# GX_5人乗り_4WD (AT_3.5_ガソリン)
# 525.3万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,950×1,980×1,925mm
# 2,360kg
# 5名
# 3,444cc
# プレミアム
# -
# 8.0km/L
# -
# 415ps（305kw）/5,200rpm
# 66.3kg・m（650N・m）/3,600rpm
# 5.9m
# ガソリン
# AX_7人乗り_4WD (AT_3.5_ガソリン)
# 563.1万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,950×1,980×1,925mm
# 2,430kg
# 7名
# 3,444cc
# プレミアム
# -
# 8.0km/L
# -
# 415ps（305kw）/5,200rpm
# 66.3kg・m（650N・m）/3,600rpm
# 5.9m
# ガソリン
# VX_7人乗り_4WD (AT_3.5_ガソリン)
# 643.6万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,950×1,980×1,925mm
# 2,440kg
# 7名
# 3,444cc
# プレミアム
# -
# 7.9km/L
# -
# 415ps（305kw）/5,200rpm
# 66.3kg・m（650N・m）/3,600rpm
# 5.9m
# ガソリン
# ZX_7人乗り_4WD (AT_3.5_ガソリン)
# 743.6万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,985×1,980×1,925mm
# 2,500kg
# 7名
# 3,444cc
# プレミアム
# -
# 7.9km/L
# -
# 415ps（305kw）/5,200rpm
# 66.3kg・m（650N・m）/3,600rpm
# 5.9m
# ガソリン
# ZX_5人乗り_4WD (AT_3.3_ディーゼル)
# 773.6万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,985×1,980×1,925mm
# 2,550kg
# 5名
# 3,345cc
# 軽油
# -
# 9.7km/L
# -
# 307ps（226kw）/4,000rpm
# 71.4kg・m（700N・m）/2,600rpm
# 5.9m
# ディーゼル
# GRスポーツ_7人乗り_4WD (AT_3.5_ガソリン)
# 783.6万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,965×1,990×1,925mm
# 2,520kg
# 7名
# 3,444cc
# プレミアム
# -
# 7.9km/L
# -
# 415ps（305kw）/5,200rpm
# 66.3kg・m（650N・m）/3,600rpm
# 5.9m
# ガソリン
# GRスポーツ_5人乗り_4WD (AT_3.3_ディーゼル)
# 813.7万円
# 2025年3月
# AWD（全輪駆動）
# ECT
# 4,965×1,990×1,925mm
# 2,560kg
# 5名
# 3,345cc
# 軽油
# -
# 9.7km/L
# -
# 307ps（226kw）/4,000rpm
# 71.4kg・m（700N・m）/2,600rpm
# 5.9m
# ディーゼル
